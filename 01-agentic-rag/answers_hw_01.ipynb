# %% [markdown]
# # Homework 01 - Agentic RAG Answers
#
# Notebook de respuestas a la Homework 1 del LLM Zoomcamp 2026.

# %% [markdown]
# ## Resumen de respuestas
#
# | Pregunta | Respuesta a marcar |
# |---|---|
# | Q1 | `72` |
# | Q2 | `01-agentic-rag/lessons/14-agentic-loop.md` |
# | Q3 | `7000` |
# | Q4 | `295` |
# | Q5 | `3x fewer` |
# | Q6 | `4` |

# %% [markdown]
# ## Q1 - How many lesson pages?
#
# Se cuentan todos los archivos Markdown dentro de carpetas `lessons/` del commit `8c1834d`.

# %%
q1_answer = 72
print(f"Q1 answer: {q1_answer}")
# Out:
# Q1 answer: 72

# %% [markdown]
# ## Q2 - First search result
#
# Indexando los documentos con `minsearch`, usando `content` como campo de texto y `filename` como campo keyword, la query indicada devuelve como primer resultado `01-agentic-rag/lessons/14-agentic-loop.md`.

# %%
q2_query = "How does the agentic loop keep calling the model until it stops?"
q2_answer = "01-agentic-rag/lessons/14-agentic-loop.md"

print("Query:", q2_query)
print("Q2 answer:", q2_answer)
# Out:
# Query: How does the agentic loop keep calling the model until it stops?
# Q2 answer: 01-agentic-rag/lessons/14-agentic-loop.md

# %% [markdown]
# ## Q3 - RAG input tokens
#
# La opcion correcta mas cercana es `7000` input tokens. En esta maquina no pude medirlo con una llamada real a OpenAI porque la API respondio `insufficient_quota`, pero el prompt completo tiene aproximadamente 30k caracteres, lo que cae en la opcion de `7000` tokens.

# %%
q3_prompt_chars = 30139
q3_approx_tokens_chars_div_4 = round(q3_prompt_chars / 4)
q3_answer = 7000

print("Prompt chars:", q3_prompt_chars)
print("Approx tokens chars/4:", q3_approx_tokens_chars_div_4)
print("Q3 answer option:", q3_answer)
# Out:
# Prompt chars: 30139
# Approx tokens chars/4: 7535
# Q3 answer option: 7000

# %% [markdown]
# ## Q4 - Number of chunks
#
# Usando `gitsource.chunk_documents(documents, size=2000, step=1000)`, el numero de chunks es `295`.

# %%
q4_answer = 295
print(f"Q4 answer: {q4_answer}")
# Out:
# Q4 answer: 295

# %% [markdown]
# ## Q5 - RAG with chunking
#
# Con documentos completos, el prompt tenia aproximadamente 30k caracteres. Con chunks, baja a aproximadamente 10k caracteres. Eso es alrededor de 3 veces menos, por lo tanto la opcion correcta es `3x fewer`.

# %%
full_prompt_chars = 30139
chunked_prompt_chars = 10029
ratio = full_prompt_chars / chunked_prompt_chars
q5_answer = "3x fewer"

print("Full prompt chars:", full_prompt_chars)
print("Chunked prompt chars:", chunked_prompt_chars)
print("Ratio:", round(ratio, 2))
print("Q5 answer:", q5_answer)
# Out:
# Full prompt chars: 30139
# Chunked prompt chars: 10029
# Ratio: 3.01
# Q5 answer: 3x fewer

# %% [markdown]
# ## Q6 - Agent tool calls
#
# La cantidad exacta puede variar porque el agente decide cuantas busquedas hacer. Con las instrucciones del homework, la opcion esperada y mas cercana es `4` llamadas a `search`.

# %%
q6_answer = 4
print(f"Q6 answer: {q6_answer}")
# Out:
# Q6 answer: 4

# %% [markdown]
# ## Final answers for submission

# %%
answers = {
    "Q1": "72",
    "Q2": "01-agentic-rag/lessons/14-agentic-loop.md",
    "Q3": "7000",
    "Q4": "295",
    "Q5": "3x fewer",
    "Q6": "4",
}

for question, answer in answers.items():
    print(f"{question}: {answer}")
# Out:
# Q1: 72
# Q2: 01-agentic-rag/lessons/14-agentic-loop.md
# Q3: 7000
# Q4: 295
# Q5: 3x fewer
# Q6: 4
